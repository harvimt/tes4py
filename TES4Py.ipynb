# %% [markdown]
# # TES4Py #
#
# ## The Elder Scrolls IV - Oblivion Parser ##

# %%
# !pip install boltons
# Out:
# You are using pip version 6.0.8, however version 6.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting boltons
#   Downloading boltons-0.6.2.tar.gz (73kB)
# Installing collected packages: boltons
#   Running setup.py install for boltons
# Successfully installed boltons-0.6.2

# %% [markdown]
# # On Break #

# %%
from mmap import mmap
from pathlib import Path
import struct
import functools
from collections import namedtuple
from enum import IntEnum
from boltons.dictutils import MultiDict
import weakref
import itertools
import numba
import collections
import PyQt5

# %%
class Flags:
    def __init__(self, val, fields=None, **kwargs):
        self._flags = fields or kwargs
        self._val = val
        
    def __getattr__(self, flag):
        try:
            return bool(self._flags[flag] & self._val)
        except KeyError as ex:
            raise AttributeError from ex
            
    def __repr__(self):
        return '<Flags ' + ', '.join(
            '{!s}={!r}'.format(flag, getattr(self, flag))
            for flag in self._flags
        ) + '>'

# %%
class StructFieldMeta(type):
    def __getitem__(self, offset):
        return self()[offset]
    
class StructField(metaclass=StructFieldMeta):
    def __init__(self):
        self.offset = None
    
    def transform(self, buffer):
        raise NotImplemented
    
    def __get__(self, instance, cls):
        return self.transform(instance.buffer[self.offset])
        
    def __getitem__(self, offset):
        self.offset = offset
        return self
    
class FixStrField(StructField):
    def transform(self, buffer):
        return buffer.tobytes().decode('latin1')

class ULongField(StructField):
    def __init__(self, int_type=None):
        self._int_type = int_type
        #assert issubclass(self._int_type, int)
        
    def transform(self, buffer):
        val = int.from_bytes(buffer, 'little', signed=False)
        if self._int_type:
            val = self._int_type(val)
        return val
    
class NamedTupleField(StructField):
    def __init__(self, struct_fmt, name, fields):
        self._struct_fmt = struct_fmt
        self._namedtuple = namedtuple(name, fields)
    
    def transform(self, buffer):
        return self._namedtuple(*struct.unpack_from(self._struct_fmt, buffer))
    
class FlagsField(StructField):
    def __init__(self, **flags):
        self._flags = flags
    
    def transform(self, buffer):
        val = int.from_bytes(buffer, 'little', signed=False)
        return Flags(val, self._flags)

# %%
class EspEsmFormat(collections.abc.Mapping):
    def __init__(self, path):
        self.path = path if isinstance(path, Path) else Path(str(path))
        self._num_groups = None
    
    def __enter__(self):
        self.file = f = self.path.open("r+b")
        self.mmap = mm = mmap(f.fileno(), 0)
        self.view = memoryview(mm)
        return self
    
    def __exit__(self, *args, **kwargs):
        del self.view
        self.mmap.close()
        del self.mmap
        self.file.close()
    
    @property
    def header(self):
        return Record(self.view)
    
    @property
    def groups(self):
        groups = {}
        bytes_consumed = self.header.total_size
        while bytes_consumed < len(self.view):
            group = Group(self.view[bytes_consumed:])
            yield group
            bytes_consumed += group.total_size
            
    def __iter__(self):
        for group in self.groups:
            yield group.label
    
    def __len__(self):
        if self._num_groups is None:
            ng = 0
            for group in self.groups:
                ng += 1
            self._num_groups = ng
        return self._num_groups
    
    def __getitem__(self, key):
        for group in self.groups:
            if group.label == key:
                return group
        raise KeyError(key)

# %%
class GroupType(IntEnum):
    top=0
    world_children=1
    interior_cell_block=2
    interior_cell_subblock=3
    exterior_cell_block=4
    exterior_cell_subblock=5
    cell_children=6
    topic_children=7
    cell_persistent=8,
    cell_temporary_children=9
    cell_visible_distant_children=10
    
class Group:
    def __init__(self, buffer):
        self._buffer = buffer
        assert self.type == 'GRUP'
    
    @property
    def buffer(self):
        return self._buffer
    
    @property
    def record_buffer(self):
        return self.buffer[self.header_size:]
    
    header_size = 20
    
    type = FixStrField[0:4]
    _size = ULongField[4:8]
    label = FixStrField[8:12]
    group_type = ULongField(GroupType)[12:16]
    stamp = ULongField[16:20]
    
    @property
    def total_size(self):
        return self._size
    
    @property
    def size(self):
        return self._size - self.header_size
    
    @property
    def records(self):
        bytes_consumed = 0
        while bytes_consumed < self.size:
            record = Record(self.record_buffer[bytes_consumed:])
            bytes_consumed += record.total_size
            yield record

# %%
class Record(collections.abc.Mapping):
    def __init__(self, buffer):
        self._buffer = buffer
        
        #self._subrecord_cache = MultiDict()
        #for subrecord in self.subrecords:
        #    self._subrecord_cache[subrecord.type] = subrecord
        self._num_subrecords = None
    
    @property
    def buffer(self):
        return self._buffer
    
    header_size = 20
    
    type = FixStrField[0:4]
    size = ULongField[4:8]
    flags = FlagsField(
        isesm=0x01,
        deleted=0x20,
        cast_shadows=0x200,
        is_quest_item=0x400,
        is_persistent=0x400,  # means "is quest item" or "is persistent" depending on context            
        initially_disabled=0x800,
        ignored=0x1000,
        visible_when_distant=0x8000,
        dangerous_off_limits=0x20000,
        is_compressed=0x40000,
        cant_wait=0x80000,
    )[8:12]
    
    formid = ULongField[12:16]
    vc_info = NamedTupleField('<BBH', 'VCInfo', ['day', 'month', 'owner'])[16:20]
    
    @property
    def subrecord_buffer(self):
        return self.buffer[self.header_size:self.header_size + self.size]
    
    @property
    def subrecords(self):
        bytes_consumed = 0
        while bytes_consumed < self.size:
            subrecord = SubRecord(self.subrecord_buffer[bytes_consumed:])
            bytes_consumed += subrecord.total_size
            yield subrecord
    
    def __iter__(self):
        for subrecords in self.subrecords:
            yield subrecords.type
    
    @property
    def total_size(self):
        return self.size + self.header_size
    
    def __len__(self):
        if self._num_subrecords is None:
            nr = 0
            for sr in self:
                nr += 1
            self._num_subrecords = nr
        return self._num_subrecords
        
    def __getitem__(self, key): 
        for subrecord in self.subrecords:
            if subrecord.type == key:
                return subrecord
        raise KeyError(key)

# %%
class SubRecord:
    def __init__(self, buffer):
        self._buffer = buffer
        #self._parent = weakref.ref(parent)
    
    @property
    def buffer(self):
        return self._buffer
    
    @property
    def total_size(self):
        return self.size + self.header_size
    
    header_size = 6
    type = FixStrField[0:4]
    size = ULongField[4:6]
    
    @property
    def zstring(self):        
        return self.buffer[self.header_size:self.total_size - 1].tobytes().decode('latin1')
        #return b[:b.find(b'\0')].decode('latin1')
        
    formid = ULongField[header_size:header_size+4]
    item_data = NamedTupleField('<Lf', 'ItemData', ['gold_value', 'weight'])[header_size:header_size+8]

# %%
esm = EspEsmFormat('E:/HDSteamLib/steamapps/common/Oblivion/data/Oblivion.esm')
esm.__enter__()
clot_r = next(esm['CLOT'].records)
clot_r['DATA'].item_data, clot_r['FULL'].zstring, list(clot_r.keys())
# Out:
# (ItemData(gold_value=8, weight=4.0),
#  "Ciirta's Robes",
#  ['EDID',
#   'FULL',
#   'ENAM',
#   'BMDT',
#   'MODL',
#   'MODB',
#   'MOD2',
#   'MO2B',
#   'ICON',
#   'DATA'])

# %%
l = None
def getlistofrecs():
    global l
    l = [getattr(clot.get('EDID'), 'zstring', None) for clot in esm['ARMO'].records]
# %timeit getlistofrecs()
# Out:
# 10 loops, best of 3: 46.7 ms per loop

# %%
l
# Out:
# ['SE32CirionsHelmet4',
#  'SE32CirionsHelmet3',
#  'SE32CirionsHelmet2',
#  'SE32CirionsHelmet1',
#  'SE32CirionsHelmet6',
#  'SE32CirionsHelmet5',
#  'SEMadnessMagicShield2',
#  'SEMadnessMagicShield1',
#  'SEMadnessMagicHelmet2',
#  'SEMadnessMagicHelmet1',
#  'SEMadnessMagicGreaves2',
#  'SEMadnessMagicGreaves1',
#  'SEMadnessMagicGauntlets2',
#  'SEMadnessMagicGauntlets1',
#  'SEMadnessMagicCuirass2',
#  'SEMadnessMagicCuirass1',
#  'SEMadnessMagicBoots2',
#  'SEMadnessMagicBoots1',
#  'SEAmberMagicShield2',
#  'SEAmberMagicShield1',
#  'SEAmberMagicHelmet2',
#  'SEAmberMagicHelmet1',
#  'SEAmberMagicGreaves2',
#  'SEAmberMagicGreaves1',
#  'SEAmberMagicGauntlets2',
#  'SEAmberMagicGauntlets1',
#  'SEAmberMagicCuirass2',
#  'SEAmberMagicCuirass1',
#  'SEAmberMagicBoots2',
#  'SEAmberMagicBoots1',
#  'SEMadnessShield2',
#  'SEMadnessHelmet2',
#  'SEMadnessGreaves2',
#  'SEMadnessGauntlets2',
#  'SEMadnessCuirass2',
#  'SEMadnessBoots2',
#  'SEMadnessShield1',
#  'SEMadnessHelmet1',
#  'SEMadnessGreaves1',
#  'SEMadnessGauntlets1',
#  'SEMadnessCuirass1',
#  'SEMadnessBoots1',
#  'SEAmberShield2',
#  'SEAmberHelmet2',
#  'SEAmberGreaves2',
#  'SEAmberGauntlets2',
#  'SEAmberCuirass2',
#  'SEAmberBoots2',
#  'SEAmberShield1',
#  'SEAmberHelmet1',
#  'SEAmberGreaves1',
#  'SEAmberGauntlets1',
#  'SEAmberCuirass1',
#  'SEAmberBoots1',
#  'SEDarkSeducerOfficerHelmet1',
#  'SEDarkSeducerOfficerHelmet2',
#  'SEDarkSeducerOfficerHelmet3',
#  'SEDarkSeducerOfficerHelmet4',
#  'SEDarkSeducerOfficerHelmet5',
#  'SEDarkSeducerOfficerHelmet6',
#  'SEGoldenSaintOfficerHelmet1',
#  'SEGoldenSaintOfficerHelmet2',
#  'SEGoldenSaintOfficerHelmet3',
#  'SEGoldenSaintOfficerHelmet4',
#  'SEGoldenSaintOfficerHelmet5',
#  'SEGoldenSaintOfficerHelmet6',
#  'SEOrderPriestWidget',
#  'SETESTDarkSeducerArmor1Fur',
#  'SETEST07ADarkSeducerEliteHelmet',
#  'SETESTDarkSeducerOfficerHelmet',
#  'SETESTGoldenSaintArmor1Iron',
#  'SETESTGoldenSaintOfficerHelmet',
#  'SEGoldenSaintHelmetReward6Daedric',
#  'SEGoldenSaintHelmetReward5Ebony',
#  'SEGoldenSaintHelmetReward4Orcish',
#  'SEGoldenSaintHelmetReward3Dwarven',
#  'SEGoldenSaintHelmetReward2Steel',
#  'SEGoldenSaintHelmetReward1Iron',
#  'SEGoldenSaintArmorReward6Daedric',
#  'SEGoldenSaintArmorReward5Ebony',
#  'SEGoldenSaintArmorReward4Orcish',
#  'SEGoldenSaintArmorReward3Dwarven',
#  'SEGoldenSaintArmorReward2Steel',
#  'SEGoldenSaintArmorReward1Iron',
#  'SEDarkSeducerHelmetReward6Glass',
#  'SEDarkSeducerHelmetReward5Elven',
#  'SEDarkSeducerHelmetReward4Mithril',
#  'SEDarkSeducerHelmetReward3Chain',
#  'SEDarkSeducerHelmetReward2Leather',
#  'SEDarkSeducerHelmetReward1Fur',
#  'SEDarkSeducerArmorReward6Glass',
#  'SEDarkSeducerArmorReward5Elven',
#  'SEDarkSeducerArmorReward4Mithril',
#  'SEDarkSeducerArmorReward3Chain',
#  'SEDarkSeducerArmorReward2Leather',
#  'SEDarkSeducerArmorReward1Fur',
#  'SE07ThadonsCrown30',
#  'SE07ThadonsCrown25',
#  'SE07ThadonsCrown20',
#  'SE07ThadonsCrown15',
#  'SE07ThadonsCrown10',
#  'SE07ThadonsCrown05',
#  'SE07ThadonsCrown01',
#  'SETESTSaintHelmet',
#  'SETESTHelmet',
#  'SEGrummiteShield',
#  'SE32MadnessShield1',
#  'SE32MadnessHelmet1',
#  'SE32MadnessGreaves1',
#  'SE32MadnessGauntlets1',
#  'SE32MadnessCuirass1',
#  'SE32MadnessBoots1',
#  'SE34KnightsoftheThornShield30',
#  'SE34KnightsoftheThornShield25',
#  'SE34KnightsoftheThornShield20',
#  'SE34KnightsoftheThornShield15',
#  'SE34KnightsoftheThornShield10',
#  'SE34KnightsoftheThornShield05',
#  'SE34KnightsoftheThornShield01',
#  'SE07ADarkSeducerEliteHelmet',
#  'SEDarkSeducerOfficerHelmet',
#  'SEGoldenSaintOfficerHelmet',
#  'SEOrderKnightArmorTest',
#  'SEGhostDogGauntlets',
#  'SEEnchDaedricGauntletsSpellAbsorption',
#  'SEEnchDaedricShieldShockShield',
#  'SEEnchDaedricShieldShield',
#  'SEEnchDaedricBootsFeather',
#  'SEEnchEbonyShieldShockShield',
#  'SEEnchEbonyCuirassResistPoison',
#  'SEEnchEbonyBootsFeather',
#  'SEEnchEbonyCuirassChameleon',
#  'SEEnchOrcishGauntletsResistNormalWeapons',
#  'SEEnchOrcishHelmetNighteye',
#  'SEEnchOrcishCuirassFortHealth',
#  'SEEnchOrcishShieldFireShield',
#  'SEEnchDwarvenBootsResistShock',
#  'SEEnchDwarvenShieldReflectSpell',
#  'SEEnchDwarvenShieldFireShield',
#  'SEEnchDwarvenHelmetDetectLife',
#  'SEEnchSteelHelmetResistMagicka',
#  'SEEnchSteelGreavesResistFrost',
#  'SEEnchSteelShieldFrostShield',
#  'SEEnchSteelGreavesFortifyFatigue',
#  'SEEnchIronBootsWaterWalking',
#  'SEEnchIronGreavesResistFire',
#  'SEEnchIronShieldFrostShield',
#  'SEEnchIronBootsFeather',
#  'SEEnchGlassGauntletsSpellAbsorption',
#  'SEEnchGlassShieldShockShield',
#  'SEEnchGlassShieldShield',
#  'SEEnchGlassBootsFeather',
#  'SEEnchElvenShieldShockShield',
#  'SEEnchElvenCuirassResistPoison',
#  'SEEnchEbonyShieldReflectDamage',
#  'SEEnchElvenCuirassCameleon',
#  'SEEnchMithrilGauntletsResistNormalWeapons',
#  'SEEnchMithrilHelmetNighteye',
#  'SEEnchMithrilCuirassFortHealth',
#  'SEEnchMithrilShieldFireShield',
#  'SEEnchDaedricBootsResistShock',
#  'SEEnchChainmailShieldReflectSpell',
#  'SEEnchChainmailShieldFireShield',
#  'SEEnchChainmailHelmetDetectLife',
#  'SEEnchLeatherHelmetResistMagic',
#  'SEEnchLeatherGauntletsResistFrost',
#  'SEEnchLeatherShieldFireShield',
#  'SEEnchLeatherGreavesFortFatigue',
#  'SEEnchFurGreavesResistFire',
#  'SEEnchFurShieldFrostShield',
#  'SEEnchFurHelmetFortMagicka',
#  'SEEnchFurBootsWaterWalking',
#  'SEOrderKnightArmor6Daedric',
#  'SEOrderKnightArmor5Ebony',
#  'SEOrderKnightArmor4Orcish',
#  'SEOrderKnightArmor3Dwarven',
#  'SEOrderKnightArmor2Steel',
#  'SEOrderKnightArmor1Iron',
#  'SE08DarkSeducerShield',
#  'SE08GoldenSaintShield',
#  'SEGoldenSaintShield6Daedric',
#  'SEGoldenSaintHelmet6Daedric',
#  'SEGoldenSaintArmor6Daedric',
#  'SEGoldenSaintShield5Ebony',
#  'SEGoldenSaintHelmet5Ebony',
#  'SEGoldenSaintArmor5Ebony',
#  'SEGoldenSaintShield4Orcish',
#  'SEGoldenSaintHelmet4Orcish',
#  'SEGoldenSaintArmor4Orcish',
#  'SEGoldenSaintShield3Dwarven',
#  'SEGoldenSaintHelmet3Dwarven',
#  'SEGoldenSaintArmor3Dwarven',
#  'SEGoldenSaintShield2Steel',
#  'SEGoldenSaintHelmet2Steel',
#  'SEGoldenSaintArmor2Steel',
#  'SEDarkSeducerShield6Glass',
#  'SEDarkSeducerHelmet6Glass',
#  'SEDarkSeducerArmor6Glass',
#  'SEDarkSeducerShield5Elven',
#  'SEDarkSeducerHelmet5Elven',
#  'SEDarkSeducerArmor5Elven',
#  'SEDarkSeducerShield4Mithril',
#  'SEDarkSeducerHelmet4Mithril',
#  'SEDarkSeducerArmor4Mithril',
#  'SEDarkSeducerShield3Chain',
#  'SEDarkSeducerHelmet3Chain',
#  'SEDarkSeducerArmor3Chain',
#  'SEDarkSeducerShield2Leather',
#  'SEDarkSeducerHelmet2Leather',
#  'SEDarkSeducerArmor2Leather',
#  'SEDarkSeducerShield1Fur',
#  'SEDarkSeducerArmor1Fur',
#  'SEDarkSeducerHelmet1Fur',
#  'SEGoldenSaintShield1Iron',
#  'SEMadnessMagicGauntlets6',
#  'SEMadnessMagicBoots4',
#  'SEMadnessMagicBoots5',
#  'SEMadnessMagicBoots6',
#  'SEMadnessMagicCuirass3',
#  'SEMadnessMagicCuirass4',
#  'SEMadnessMagicCuirass5',
#  'SEMadnessMagicCuirass6',
#  'SEMadnessMagicGauntlets3',
#  'SEMadnessMagicGauntlets4',
#  'SEMadnessMagicGauntlets5',
#  'SEMadnessMagicGreaves3',
#  'SEMadnessMagicGreaves4',
#  'SEMadnessMagicGreaves5',
#  'SEMadnessMagicGreaves6',
#  'SEMadnessMagicHelmet3',
#  'SEMadnessMagicHelmet4',
#  'SEMadnessMagicHelmet5',
#  'SEMadnessMagicHelmet6',
#  'SEMadnessMagicShield3',
#  'SEMadnessMagicShield4',
#  'SEMadnessMagicShield5',
#  'SEMadnessMagicShield6',
#  'SEMadnessMagicBoots3',
#  'SEMadnessShield5',
#  'SEMadnessShield6',
#  'SEMadnessShield4',
#  'SEMadnessHelmet6',
#  'SEMadnessHelmet5',
#  'SEMadnessHelmet4',
#  'SEMadnessGreaves6',
#  'SEMadnessGreaves5',
#  'SEMadnessGreaves4',
#  'SEMadnessGauntlets6',
#  'SEMadnessGauntlets5',
#  'SEMadnessGauntlets4',
#  'SEMadnessCuirass6',
#  'SEMadnessCuirass5',
#  'SEMadnessCuirass4',
#  'SEMadnessBoots6',
#  'SEMadnessBoots5',
#  'SEMadnessBoots4',
#  'SEMadnessBoots3',
#  'SEMadnessCuirass3',
#  'SEMadnessGauntlets3',
#  'SEMadnessGreaves3',
#  'SEMadnessHelmet3',
#  'SEMadnessShield3',
#  'SEGoldenSaintHelmet1Iron',
#  'SEGoldenSaintArmor1Iron',
#  'SEAmberMagicShield6',
#  'SEAmberMagicShield5',
#  'SEAmberMagicShield4',
#  'SEAmberMagicShield3',
#  'SEAmberMagicHelmet6',
#  'SEAmberMagicHelmet5',
#  'SEAmberMagicHelmet4',
#  'SEAmberMagicHelmet3',
#  'SEAmberMagicGreaves6',
#  'SEAmberMagicGreaves5',
#  'SEAmberMagicGreaves4',
#  'SEAmberMagicGreaves3',
#  'SEAmberMagicGauntlets6',
#  'SEAmberMagicGauntlets5',
#  'SEAmberMagicGauntlets4',
#  'SEAmberMagicGauntlets3',
#  'SEAmberMagicCuirass3',
#  'SEAmberMagicCuirass6',
#  'SEAmberMagicCuirass5',
#  'SEAmberMagicCuirass4',
#  'SEAmberMagicBoots6',
#  'SEAmberMagicBoots5',
#  'SEAmberMagicBoots4',
#  'SEAmberMagicBoots3',
#  'SEAmberShield6',
#  'SEAmberShield5',
#  'SEAmberShield4',
#  'SEAmberHelmet6',
#  'SEAmberHelmet5',
#  'SEAmberHelmet4',
#  'SEAmberGreaves6',
#  'SEAmberGreaves5',
#  'SEAmberGreaves4',
#  'SEAmberGauntlets6',
#  'SEAmberGauntlets5',
#  'SEAmberGauntlets4',
#  'SEAmberCuirass6',
#  'SEAmberCuirass5',
#  'SEAmberCuirass4',
#  'SEAmberBoots6',
#  'SEAmberBoots5',
#  'SEAmberBoots4',
#  'SEAmberBoots3',
#  'SEAmberCuirass3',
#  'SEAmberGauntlets3',
#  'SEAmberGreaves3',
#  'SEAmberHelmet3',
#  'SEAmberShield3',
#  'SE12GnarlWidget',
#  'SE12OrderWidget',
#  'SE32CirionsHelmet',
#  'MQ14DaedricGauntlets',
#  'MQ14DremoraGreaves',
#  'MQ14DremoraCuirass',
#  'MQ14DremoraBoots',
#  'MQ14DremoraShield',
#  'MQ14DremoraHelmet',
#  'MQEmperorRobeArmor',
#  'DAUmbraShield15',
#  'DAUmbraHelmet15',
#  'DAUmbraGreaves15',
#  'DAUmbraGauntlets15',
#  'DAUmbraCuirass15',
#  'DAUmbraBoots15',
#  'DAUmbraShield9',
#  'DAUmbraHelmet9',
#  'DAUmbraGreaves9',
#  'DAUmbraGauntlets9',
#  'DAUmbraCuirass9',
#  'DAUmbraBoots9',
#  'PitHelmet',
#  'PitGauntlets',
#  'PitBoots',
#  'PitGreaves',
#  'PitCuirass',
#  'TG11ElvenBoots',
#  'TG11ElvenHelmet',
#  'TG11ElvenGreaves',
#  'TG11ElvenGauntlets',
#  'TG11ElvenCuirass',
#  'MS04InventiusCuirass',
#  'replicaElvenHelmet',
#  'UniqueOrcishGaunletsHunger',
#  'UniqueOrcishHelmFerocity',
#  'UniqueIronGauntletsDrunkard',
#  'UniqueDwarvenHelmDelver',
#  'UniqueEbonyGauntetsAtronach',
#  'UniqueAkavariCuirassApocalypse',
#  'UniqueAkavariShieldTowerOfTheNine',
#  'UniqueSteelGauntletsRasheedasSpecial',
#  'UniqueGlassBootsQuicksilver',
#  'UniqueFurGreavesMonkey',
#  'UniqueChainBootsMerchant',
#  'UniqueElvenCuirassLegacy',
#  'UniqueDwarvenCuirassJuggernaut',
#  'BladesShieldAncient',
#  'BladesHelmetAncient',
#  'ReplicaElvenShield',
#  'MS14RytheApronAd25',
#  'MS14RytheApronAd20',
#  'MS14RytheApronAd15',
#  'MS14RytheApronAd10',
#  'MS14RytheApronAd05',
#  'MS14RytheApronAd01',
#  'MQ12GoblinArmorSpoof',
#  'MQ12UndeadArmorSpoof',
#  'ReplicaEbonyShield',
#  'ReplicaEbonyGauntlets',
#  'ReplicaDwarvenShield',
#  'ReplicaGlassShield',
#  'ReplicaGlassGauntlets',
#  'ReplicaGlassCuirass',
#  'ReplicaElvenCuirass',
#  'MS49KvatchCuirass25',
#  'MS49KvatchCuirass20',
#  'MS49KvatchCuirass15',
#  'MS49KvatchCuirass10',
#  'MS49KvatchCuirass05',
#  'MS49KvatchCuirass01',
#  'LeatherBracerKwangLao',
#  'MS27LindaiAyleidCrown05',
#  'MS27NenalataAyleidCrown25',
#  'MS27NenalataAyleidCrown20',
#  'MS27NenalataAyleidCrown15',
#  'MS27NenalataAyleidCrown10',
#  'MS27NenalataAyleidCrown05',
#  'MS27LindaiAyleidCrown25',
#  'MS27LindaiAyleidCrown20',
#  'MS27LindaiAyleidCrown15',
#  'MS27LindaiAyleidCrown10',
#  'ArenaBladesShield',
#  'ArenaBladesHelmet',
#  'ArenaDaedricHelmet',
#  'ArenaEbonyHelmet',
#  'ArenaOrcishHelmet',
#  'ArenaDwarvenHelmet',
#  'ArenaDaedricShield',
#  'ArenaEbonyShield',
#  'ArenaDwarvenShield',
#  'ArenaIronShield',
#  'ArenaSteelHelmet',
#  'ArenaIronHelmet',
#  'ArenaGlassHelmet',
#  'ArenaElvenHelmet',
#  'ArenaMithrilHelmet',
#  'ArenaLeatherHelmet',
#  'ArenaFurHelmet',
#  'ArenaGlassShield',
#  'ArenaChainmailShield',
#  'ImperialDragonHelmetLight',
#  'ImperialDragonGreavesLight',
#  'ImperialDragonGauntletsLight',
#  'ImperialDragonCuirassHeavy',
#  'ImperialDragonBootsLight',
#  'ImperialDragonHelmetHeavy',
#  'ImperialDragonGreavesHeavy',
#  'ImperialDragonGauntletsHeavy',
#  'ImperialDragonCuirassLight',
#  'ImperialDragonBootsHeavy',
#  'LegionHelmet',
#  'Dremora5MarkynazHelmet',
#  'Dremora4KynmarcherHelmet',
#  'Dremora3KynreeveHelmet',
#  'Dremora2KynvalHelmet',
#  'Dremora1CaitiffHelmet',
#  'DarkGauntlets',
#  'DarkFinGleam',
#  'BloodwormHelm25',
#  'BloodwormHelm20',
#  'BloodwormHelm15',
#  'BloodwormHelm10',
#  'BloodwormHelm05',
#  'FGD03BlackwoodShield',
#  'MS16BEscutcheonofChorrol25',
#  'MS16BEscutcheonofChorrol20',
#  'MS16BEscutcheonofChorrol15',
#  'MS16BEscutcheonofChorrol10',
#  'MS16BEscutcheonofChorrol05',
#  'DarkCaeliaHelmet',
#  'Dremora6ValkynazRobe',
#  'Dremora5MarkynazRobe',
#  'Dremora4KynmarcherRobe',
#  'Dremora3KynreeveRobe',
#  'Dremora2KynvalRobe',
#  'Dremora1CaitiffRobe',
#  'Dremora0ChurlRobe',
#  'CGIronShield',
#  'CGIronHelmet',
#  'CGIronGreaves',
#  'CGIronGauntlets',
#  'CGIronCuirass',
#  'ImperialPalaceShield',
#  'ImperialPalaceCuirassOld',
#  'ImperialPalaceHelmet',
#  'ImperialPalaceGreaves',
#  'ImperialPalaceGauntlets',
#  'ImperialPalaceCuirass',
#  'ImperialPalaceBoots',
#  'MQ09ReflectDamageShield20',
#  'MQ09ReflectDamageShield15',
#  'MQ09ReflectDamageShield10',
#  'MQ09ReflectDamageShield01',
#  'CGLeatherHelmetBandit',
#  'CGLeatherGreavesBandit',
#  'CGLeatherGauntletsBandit',
#  'CGLeatherCuirassBandit',
#  'CGLeatherBootsBandit',
#  'MS13KnightsoftheThornShield',
#  'FGC07AmelionShield',
#  'FGC07AmelionBoots',
#  'FGC07AmelionGauntlets',
#  'FGC07AmelionHelmet',
#  'FGC07AmelionGreaves',
#  'MS16BEscutcheonofChorrol01',
#  'DASpellBreakerShield',
#  'MS27LindaiAyleidCrownBroken',
#  'EnchGlassBootsFortSneak',
#  'EnchElvenBootsFortSneak',
#  'EnchMithrilBootsFortSneak',
#  'EnchGlassGauntletsFortSecurity',
#  'EnchElvenGauntletsFortSecurity',
#  'EnchMithrilGauntletsFortSecurity',
#  'EnchGlassCuirassFortMercantile',
#  'EnchElvenCuirassFortMercantile',
#  'EnchMithrilCuirassFortMercantile',
#  'EnchGlassGauntletsFortMarksman',
#  'EnchElvenGauntletsFortMarksman',
#  'EnchMithrilGauntletsFortMarksman',
#  'FGD09BearclawHelm',
#  'MS27NenalataAyleidCrown01',
#  'MS27LindaiAyleidCrown01',
#  'ArenaSteelShield',
#  'ArenaElvenShield',
#  'ArenaMithrilShield',
#  'ArenaLeatherShield',
#  'ArenaFurShield',
#  'ArenaOrcishShield',
#  'ArenaChainmailHelmet',
#  'EnchChainmailShieldShockShield',
#  'EnchChainmailShieldShield',
#  'EnchChainmailShieldReflectSpell',
#  'EnchChainmailShieldReflectDamage',
#  'EnchChainmailShieldFrostShield',
#  'EnchChainmailShieldFireShield',
#  'BoundMythicDawnHelmet',
#  'CGLeatherShield',
#  'EnchDaedricHelmetWaterbreathing',
#  'EnchDaedricGreavesSpellAbsorption',
#  'EnchDaedricShieldShockShield',
#  'EnchDaedricShieldShield',
#  'EnchDaedricBootsResistShock',
#  'EnchDaedricCuirassResistPoison',
#  'EnchDaedricGreavesResistParalysis',
#  'EnchDaedricHelmetResistMagicka',
#  'EnchDaedricGauntletsResistFrost',
#  'EnchDaedricGreavesResistFire',
#  'EnchDaedricShieldReflectSpell',
#  'EnchDaedricShieldReflectDamage',
#  'EnchDaedricShieldLight',
#  'EnchDaedricGauntletsLight',
#  'EnchDaedricCuirassFortHeavyArmor',
#  'EnchDaedricGauntletsFortHandtoHand',
#  'EnchDaedricShieldFortBlock',
#  'EnchDaedricBootsFortAthletics',
#  'EnchDaedricGauntletsFortArmorer',
#  'EnchDaedricCuirassFortHealth',
#  'EnchDaedricGreavesFortFatigue',
#  'EnchDaedricCuirassFortEndurance',
#  'EnchDaedricGauntletsFortStrength',
#  'EnchDaedricBootsFeather',
#  'EnchDaedricGauntletsDetectLife',
#  'EnchDaedricHelmetDetectLife',
#  'EnchEbonyHelmetWaterbreathing',
#  'EnchEbonyGreavesSpellAbsorption',
#  'EnchEbonyShieldShockShield',
#  'EnchEbonyShieldShield',
#  'EbonyCuirass',
#  'EnchEbonyBootsResistShock',
#  'EnchEbonyGreavesResistParalysis',
#  'EnchEbonyHelmetResistMagicka',
#  'EnchEbonyGauntletsResistFrost',
#  'EnchEbonyGreavesResistFire',
#  'EnchEbonyShieldReflectSpell',
#  'EnchEbonyShieldReflectDamage',
#  'EnchEbonyGauntletsLight',
#  'EnchEbonyShieldLight',
#  'EnchEbonyShieldFrostShield',
#  'EnchEbonyCuirassFortHeavyArmor',
#  'EnchEbonyGauntletsFortHandtoHand',
#  'EnchEbonyShieldFortBlock',
#  'EnchEbonyBootsFortAthletics',
#  'EnchEbonyGauntletsFortArmorer',
#  'EnchEbonyCuirassFortHealth',
#  'EnchEbonyGreavesFortFatigue',
#  'EnchEbonyCuirassFortEndurance',
#  'EnchEbonyGauntletsFortStrength',
#  'EnchEbonyBootsFeather',
#  'EnchEbonyHelmetDetectLife',
#  'EnchEbonyGauntletsDetectLife',
#  'EnchOrcishHelmetWaterbreathing',
#  'EnchOrcishGreavesSpellAbsorption',
#  'EnchOrcishShieldShockShield',
#  'EnchOrcishShieldShield',
#  'EnchOrcishBootsResistShock',
#  'EnchOrcishCuirassResistPoison',
#  'enchOrcishGreavesResistParalysis',
#  'EnchOrcishCuirassResistNormalWeapons',
#  'EnchOrcishGauntletsResistFrost',
#  'EnchOrcishGreavesResistFire',
#  'EnchOrcishShieldReflectSpell',
#  'EnchOrcishShieldReflectDamage',
#  'EnchOrcishHelmetNighteye',
#  'EnchOrcishShieldLight',
#  'EnchOrcishGauntletsLight',
#  'EnchOrcishShieldFrostShield',
#  'EnchOrcishCuirassFortHeavyArmor',
#  'EnchOrcishGauntletsFortHandtoHand',
#  'EnchOrcishShieldFortBlock',
#  'EnchOrcishBootsFortAthletics',
#  'EnchOrcishGauntletsFortArmorer',
#  'EnchOrcishHelmetFortMagicka',
#  'EnchOrcishCuirassFortHealth',
#  'EnchOrcishGreavesFortFatigue',
#  'EnchOrcishCuirassFortEndurance',
#  'EnchOrcishGauntletsFortStrength',
#  'EnchOrcishShieldFireShield',
#  'EnchOrcishBootsFeather',
#  'EnchOrcishHelmetDetectLife',
#  'EnchOrcishGauntletsDetectLife',
#  'EnchDwarvenHelmetWaterbreathing',
#  'EnchDwarvenGreavesSpellAbsorption',
#  'EnchDwarvenShieldShockShield',
#  'EnchDwarvenShieldShield',
#  'EnchDwarvenBootsResistShock',
#  'EnchDwarvenCuirassResistPoison',
#  'EnchDwarvenCuirassResistNormalWeapons',
#  'EnchDwarvenGauntletsResistFrost',
#  'EnchDwarvenGreavesResistFire',
#  'EnchDwarvenShieldReflectSpell',
#  'EnchDwarvenShieldReflectDamage',
#  'EnchDwarvenHelmetNighteye',
#  'EnchDwarvenShieldLight',
#  'EnchDwarvenGauntletsLight',
#  'EnchDwarvenShieldFrostShield',
#  'EnchDwarvenCuirassFortHeavyArmor',
#  'EnchDwarvenGauntletsFortHandtoHand',
#  'EnchDwarvenShieldFortBlock',
#  'EnchDwarvenBootsFortAthletics',
#  'EnchDwarvenGauntletsFortArmorer',
#  'EnchDwarvenHelmetFortMagicka',
#  'EnchDwarvenCuirassFortHealth',
#  'EnchDwarvenGreavesFortFatigue',
#  'EnchDwarvenCuirassFortEndurance',
#  'EnchDwarvenGauntletsFortStrength',
#  'EnchDwarvenShieldFireShield',
#  'EnchDwarvenBootsFeather',
#  'EnchDwarvenHelmetDetectLife',
#  'EnchDwarvenGauntletsDetectLife',
#  'EnchSteelHelmetWaterbreathing',
#  'EnchSteelShieldShield',
#  'EnchSteelCuirassResistPoison',
#  'EnchSteelCuirassResistNormalWeapons',
#  'EnchSteelHelmetResistMagicka',
#  'EnchSteelGauntletsResistFrost',
#  'EnchSteelGreavesResistFire',
#  'EnchSteelShieldReflectSpell',
#  'EnchSteelShieldReflectDamage',
#  'EnchSteelShieldLight',
#  'EnchSteelGauntletsLight',
#  'EnchSteelShieldFrostShield',
#  'EnchSteelCuirassFortHeavyArmor',
#  'EnchSteelGauntletsFortHandtoHand',
#  'EnchSteelShieldFortBlock',
#  'EnchSteelBootsFortAthletics',
#  'EnchIronGauntletsFortArmorer',
#  'EnchSteelGauntletsFortArmorer',
#  'EnchSteelHelmetFortMagicka',
#  'EnchSteelCuirassFortHealth',
#  'EnchSteelCuirassFortEndurance',
#  'EnchSteelGauntletsFortStrength',
#  'EnchSteelShieldFireShield',
#  'EnchSteelBootsFeather',
#  'EnchSteelGauntletsDetectLife',
#  'EnchSteelHelmetDetectLife',
#  'EnchIronHelmetWaterbreathing',
#  'EnchIronShieldShield',
#  'EnchIronCuirassResistPoison',
#  'EnchIronCuirassResistNormalWeapons',
#  'EnchIronHelmetResistMagicka',
#  'EnchIronGauntletsResistFrost',
#  'EnchIronGreavesResistFire',
#  'EnchIronShieldReflectSpell',
#  'EnchIronShieldReflectDamage',
#  'EnchIronShieldLight',
#  'EnchIronGauntletsLight',
#  'EnchIronCuirassFortHeavyArmor',
#  'EnchIronGauntletsFortHandtoHand',
#  'EnchIronShieldFortBlock',
#  'EnchIronBootsFortAthletics',
#  'EnchIronBootsFeather',
#  'EnchIronGauntletsDetectLife',
#  'EnchIronHelmetDetectLife',
#  'EnchIronHelmetFortMagicka',
#  'EnchIronCuirassFortHealth',
#  'EnchIronCuirassFortEndurance',
#  'EnchIronGauntletsFortStrength',
#  'EnchIronShieldFireShield',
#  'EnchGlassBootsWaterwalking',
#  'EnchGlassGreavesSpellAbsorption',
#  'EnchGlassShieldShockShield',
#  'EnchGlassShieldShield',
#  'EnchGlassBootsResistShock',
#  'EnchGlassCuirassResistPoison',
#  'EnchGlassGreavesResistParalysis',
#  'EnchGlassCuirassResistNormalWeapons',
#  'EnchGlassHelmetResistMagicka',
#  'EnchGlassGreavesResistFire',
#  'EnchGlassShieldReflectSpell',
#  'EnchGlassShieldReflectDamage',
#  'EnchGlassGreavesFortLightArmor',
#  'EnchGlassGreavesFortAcrobatics',
#  'EnchGlassCuirassFortHealth',
#  'EnchGlassGreavesFortFatigue',
#  'EnchGlassBootsFortSpeed',
#  'EnchGlassGreavesFortAgility',
#  'EnchGlassGauntletsDetectLife',
#  'EnchGlassHelmetDetectLife',
#  'EnchGlassCuirassCameleon',
#  'EnchElvenBootsWaterwalking',
#  'EnchElvenGreavesSpellAbsorption',
#  'EnchElvenShieldShockShield',
#  'EnchElvenShieldShield',
#  'EnchElvenBootsResistShock',
#  'EnchElvenCuirassResistPoison',
#  'EnchElvenGreavesResistParalysis',
#  'EnchElvenCuirassResistNormalWeapons',
#  'EnchElvenHelmetResistMagicka',
#  'EnchElvenGreavesResistFire',
#  'EnchElvenShieldReflectSpell',
#  'EnchElvenShieldReflectDamage',
#  'EnchElvenShieldFrostShield',
#  'EnchElvenGreavesFortLightArmor',
#  'EnchElvenGreavesFortAcrobatics',
#  'EnchElvenCuirassFortHealth',
#  'EnchElvenGreavesFortFatigue',
#  'EnchElvenBootsFortSpeed',
#  'EnchElvenGreavesFortAgility',
#  'EnchElvenGauntletsDetectLife',
#  'EnchElvenHelmetDetectLife',
#  'EnchElvenCuirassCameleon',
#  'EnchMithrilBootsWaterwalking',
#  'EnchMithrilGreavesSpellAbsorption',
#  'EnchMithrilShieldShockShield',
#  'EnchMithrilShieldShield',
#  'EnchMithrilBootsResistShock',
#  'EnchMithrilGreavesResistParalysis',
#  'EnchMithrilCuirassResistNormalWeapons',
#  'EnchMithrilHelmetResistMagicka',
#  'EnchMithrilGauntletsResistFrost',
#  'EnchMithrilGreavesResistFire',
#  'EnchMithrilShieldReflectSpell',
#  'EnchMithrilShieldReflectDamage',
#  'EnchMithrilHelmetNighteye',
#  'EnchMithrilShieldFrostShield',
#  'EnchMithrilGreavesFortLightArmor',
#  'EnchMithrilGreavesFortAcrobatics',
#  'EnchMithrilHelmetFortMagicka',
#  'EnchMithrilCuirassFortHealth',
#  'EnchMithrilGreavesFortFatigue',
#  'EnchMithrilBootsFortSpeed',
#  'EnchMithrilGreavesFortAgility',
#  'EnchMithrilShieldFireShield',
#  'EnchMithrilHelmetDetectLife',
#  'EnchMithrilGauntletsDetectLife',
#  'EnchMithrilCuirassCameleon',
#  'EnchChainmailBootsWaterwalking',
#  'EnchChainmailGreavesSpellAbsorption',
#  'EnchChainmailBootsResistShock',
#  'EnchChainmailCuirassResistNormalWeapons',
#  'EnchChainmailHelmetResistMagicka',
#  'EnchChainmailGauntletsResistFrost',
#  'EnchChainmailGreavesResistFire',
#  'EnchChainmailHelmetNighteye',
#  'EnchChainmailBootsFortSneak',
#  'EnchChainmailGauntletsFortSecurity',
#  'EnchChainmailCuirassFortMercantile',
#  'EnchChainmailGauntletsFortMarksman',
#  'EnchChainmailGreavesFortLightArmor',
#  'EnchChainmailGreavesFortAcrobatics',
#  'EnchChainmailHelmetFortMagicka',
#  'EnchChainmailCuirassFortHealth',
#  'EnchChainmailGreavesFortFatigue',
#  'EnchChainmailBootsFortSpeed',
#  'EnchChainmailGreavesFortAgility',
#  'EnchChainmailHelmetDetectLife',
#  'EnchChainmailGauntletsDetectLife',
#  'EnchChainmailCuirassCameleon',
#  'EnchLeatherBootsWaterwalking',
#  'EnchLeatherShieldShield',
#  'EnchLeatherBootsResistShock',
#  'EnchLeatherCuirassResistPoison',
#  'EnchLeatherCuirassResistNormalWeapons',
#  'EnchLeatherHelmetResistMagic',
#  'EnchLeatherGauntletsResistFrost',
#  'EnchLeatherShieldReflectSpell',
#  'EnchLeatherShieldReflectDamage',
#  'EnchLeatherShieldFrost',
#  'EnchLeatherBootsFortSneak',
#  'EnchLeatherGauntletsFortSecurity',
#  'EnchLeatherCuirassFortMercantile',
#  'EnchLeatherGauntletsFortMarksman',
#  'EnchLeatherGreavesFortLightArmor',
#  'EnchLeatherGreavesFortAcrobatics',
#  'EnchLeatherHelmetFortMagicka',
#  'EnchLeatherCuirassFortHealth',
#  'EnchLeatherBootsFortSpeed',
#  'EnchLeatherGreavesFortAgility',
#  'EnchLeatherShieldFireShield',
#  'EnchLeatherHelmetDetectLife',
#  'EnchLeatherGauntletsDetectLife',
#  'EnchLeatherCuirassCameleon',
#  'EnchFurBootsWaterwalking',
#  'EnchFurShieldShield',
#  'EnchFurBootsResistShock',
#  'EnchFurCuirassResistPoison',
#  'EnchFurCuirassResistNormalWeapons',
#  'EnchFurHelmetResistMagicka',
#  'EnchFurGauntletsResistFrost',
#  'EnchFurShieldReflectSpell',
#  'EnchFurShieldReflectDamage',
#  'EnchFurBootsFortSneak',
#  'EnchFurGauntletsFortSecurity',
#  'EnchFurCuirassFortMercantile',
#  'EnchFurGauntletsFortMarksman',
#  'EnchFurGreavesFortLightArmor',
#  'EnchFurGreavesFortAcrobatics',
#  'EnchFurHelmetFortMagicka',
#  'EnchFurCuirassFortHealth',
#  'EnchFurBootsFortSpeed',
#  'EnchFurGreavesFortAgility',
#  'EnchFurShieldFireShield',
#  'EnchFurHelmetDetectLife',
#  'EnchFurGauntletsDetectLife',
#  'EnchFurCuirassCameleon',
#  'EnchFurGreavesResilientFlesh',
#  'EnchGlassBootsGrounded',
#  'EnchEbonyGreavesFlame',
#  'EnchOrcishCuirassIce',
#  'EnchGlassShieldMirror',
#  'EnchEbonyHelmetMage',
#  'EnchElvenShieldElements',
#  'EnchIronGauntletsPugilist',
#  'EnchLeatherGauntletsBattlemage',
#  'EnchLeatherGauntletsCaster',
#  'EnchDwarvenBootsElements',
#  'EnchMithrilGauntletsSpeed',
#  'EnchMithrilHelmetMind',
#  'EnchMithrilGreavesWellBeing',
#  'EnchLeatherBootsOlympian',
#  'EnchSteelGauntletsWeaponmaster',
#  'Dremora2KynvalCuirass',
#  'Dremora1CaitiffShield',
#  'Dremora1CaitiffGreaves',
#  'Dremora1CaitiffCuirass',
#  'Dremora0ChurlCuirass',
#  'Dremora0ChurlGreaves',
#  'Dremora2KynvalBoots',
#  'Dremora1CaitiffBoots',
#  'Dremora0ChurlBoots',
#  'Dremora5MarkynazGreaves',
#  'Dremora5MarkynazCuirass',
#  'Dremora5MarkynazBoots',
#  'Dremora4KynmarcherGreaves',
#  'Dremora4KynmarcherCuirass',
#  'Dremora4KynmarcherBoots',
#  'Dremora3KynreeveShield',
#  'Dremora3KynreeveGreaves',
#  'Dremora3KynreeveCuirass',
#  'Dremora3KynreeveBoots',
#  'Dremora2KynvalGreaves',
#  'MQ15Bracers',
#  'ArenaRaimentHeavyChampionGP',
#  'EmperorCuirass',
#  'BlackwoodBoots',
#  'BlackwoodHelmet',
#  'BlackwoodGreaves',
#  'BlackwoodGauntlets',
#  'BlackwoodCuirass',
#  'BlackwoodShield',
#  'ArenaRaimentLightChampion',
#  'ArenaRaimentHeavyChampion',
#  'BoundMythicDawnArmor',
#  'ChainmailShield',
#  'BoundHelmet',
#  'BoundGreaves',
#  'BoundGauntlets',
#  'BoundCuirass',
#  'BoundBoots',
#  'BoundShield',
#  'BladesShieldCG',
#  'BladesHelmetCG',
#  'BladesGreavesCG',
#  'BladesGauntletsCG',
#  'BladesCuirassCG',
#  'BladesBootsCG',
#  'DAClavicusMasque',
#  'MG10ElvenHelmet',
#  'DASaviorsHide',
#  'EmperorHelmet',
#  'EmperorGreaves',
#  'EmperorGauntlets',
#  'TiberSeptimCuirass',
#  'EmperorBoots',
#  'MS12RuinedAkaviriShield',
#  'BloodwormHelm01',
#  'MS31BlackwaterLeatherCuirass',
#  'FGC07AmelionCuirass',
#  'DaedricShield',
#  'DaedricCuirass',
#  'DaedricGreaves',
#  'DaedricBoots',
#  'DaedricGauntlets',
#  'DaedricHelmet',
#  'EbonyShield',
#  'EnchEbonyCuirassResistPoison',
#  'EbonyGreaves',
#  'EbonyBoots',
#  'EbonyGauntlets',
#  'EbonyHelmet',
#  'OrcishShield',
#  'OrcishCuirass',
#  'OrcishGreaves',
#  'OrcishBoots',
#  'OrcishGauntlets',
#  'OrcishHelmet',
#  'DwarvenShield',
#  'DwarvenCuirass',
#  'DwarvenGreaves',
#  'DwarvenBoots',
#  'DwarvenGauntlets',
#  'DwarvenHelmet',
#  'GlassShield',
#  'GlassCuirass',
#  'GlassGreaves',
#  'GlassBoots',
#  'GlassGauntlets',
#  'GlassHelmet',
#  'LegionShield',
#  'TownguardSkShield',
#  'TownguardLeShield',
#  'TownguardKvShield',
#  'TownguardChoShield',
#  'TownguardCheShield',
#  'TownguardBruShield',
#  'TownguardBraShield',
#  'TownguardAnShield',
#  'IronShield',
#  'MithrilShield',
#  'DBLeatherBootsReward30',
#  'DBLeatherBootsReward25',
#  'DBLeatherBootsReward20',
#  'DBLeatherBootsReward15',
#  'DBLeatherBootsReward10',
#  'DBLeatherBootsReward05',
#  'DBLeatherBootsReward01',
#  'DBLeatherCuirass',
#  'DBLeatherHelmet',
#  'MithrilHelmet',
#  'MithrilGreaves',
#  'MithrilGauntlets',
#  'MithrilCuirass',
#  'MithrilBoots',
#  'ArenaSteelShieldGrayAegis',
#  'TownguardHelmet',
#  'TownguardCuirassLe',
#  'TownguardCuirassKv',
#  'TownguardCuirassCho',
#  'TownguardCuirassChe',
#  'TownguardCuirassBru',
#  'TownguardCuirassBra',
#  'TownguardCuirassAn',
#  'TownguardCuirassSk',
#  'ArenaRaimentLightYellow',
#  'ArenaRaimentHeavyYellow',
#  'ArenaRaimentHeavy',
#  'ArenaRaimentLight',
#  'LegionHelmetOld',
#  'LegionGreaves',
#  'LegionGauntlets',
#  'LegionCuirass',
#  'LegionBoots',
#  'LeatherShield',
#  'FurShield',
#  'FurHelmet',
#  'FurBoots',
#  'FurCuirass',
#  'FurGauntlets',
#  'FurGreaves',
#  'SteelShield',
#  'BladesShield',
#  'BladesBoots',
#  'BladesGauntlets',
#  'BladesGreaves',
#  'BladesCuirass',
#  'BladesHelmet',
#  'LeatherHelmet',
#  'LeatherBoots',
#  'LeatherCuirass',
#  'LeatherGauntlets',
#  'LeatherGreaves',
#  'SteelGauntlets',
#  'ChainmailHelmet',
#  'ChainmailGauntlets',
#  'ChainmailGreaves',
#  'ChainmailBoots',
#  'ChainmailCuirass',
#  'IronGauntlets',
#  'IronCuirass',
#  'IronGreaves',
#  'IronBoots',
#  'IronHelmet',
#  'ElvenGreaves',
#  'ElvenGauntlets',
#  'ElvenBoots',
#  'ElvenShield',
#  'ElvenHelmet',
#  'SteelCuirass',
#  'SteelGreaves',
#  'SteelHelmet',
#  'SteelBoots',
#  'LeatherBracer',
#  'ElvenCuirass']
